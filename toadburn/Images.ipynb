# %%
from PIL import Image

# %%
fname = 'Mario - Walk1.gif'
Image.open(fname)
# Out:
# <PIL.GifImagePlugin.GifImageFile image mode=P size=32x32>

# %%
fname = 'Mario - Walk1.gif'
im = Image.open(fname).transpose(Image.FLIP_LEFT_RIGHT)
im.save('marioW1.gif')

# %%
fname = 'Mario - Walk2.gif'
im = Image.open(fname).transpose(Image.FLIP_LEFT_RIGHT)
im.save('marioW2.gif')

# %%
fname = 'Mario - Walk3.gif'
im = Image.open(fname).transpose(Image.FLIP_LEFT_RIGHT)
im.save('marioW3.gif')
